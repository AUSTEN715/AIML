# %%
import json

# %%
#load the data
def load_data(filename):
    with open(filename, "r") as f:
        data = json.load(f)
    return data

# %%
data = load_data("store_data.json")
print(data)
print(type(data))
# Out:
# [{'name': 'Alice', 'rating': '5', 'feedback': 'Great product!!', 'age': '25'}, {'name': 'Bob', 'rating': 'four', 'feedback': ' ok but late Delivery', 'age': '30'}, {'name': 'Charlie', 'rating': 'two', 'feedback': 'BAD EXPERIENCE ', 'age': ''}, {'name': 'Diana', 'feedback': 'Loved it!', 'rating': '5', 'age': '28'}, {'name': 'Eve', 'rating': '3.5', 'feedback': 'Average - could be better', 'age': '20'}, {'name': 'Alice', 'rating': '5', 'feedback': 'Great product again!', 'age': '25'}]
# <class 'list'>

# %%
# Clean and structure data
def clean_data(data):
    text_to_num = {"one": 1, "two": 2, "three": 3, "four": 4, "five": 5}
    cleaned_data = []
    unique_users = set()
    
    for user in data:
        #Clean Rating
        raw_rating = str(user["rating"]).strip().lower()

        if(raw_rating in text_to_num):
            raw_rating = text_to_num[raw_rating]

        user["rating"] = raw_rating

        
        #Handle missing values
        raw_age = user.get("age")  #gives None --> not exist
        if(raw_age == None):
            user["age"] = None


        #deduplication
        if(user["name"].strip() in unique_users):
            continue
            
        cleaned_data.append(user)
        unique_users.add(user["name"].strip())

    return cleaned_data

# %%
data = clean_data(data)

# %%
#Get meaningful Insights from data
def get_insights(data):

    #avg rating
    total_rating = 0
    for user in data:
        total_rating += float(user["rating"])
        
    print(f"Avg rating = {total_rating/len(structured_data)}")

    #Percentage of users with poor rating
    poor_ratings = 0
    for user in data:
        if(float(user["rating"]) < 3):
            poor_ratings += 1

    print(f"Percentage of users with poor rating = {poor_ratings/len(structured_data) * 100}%")

# %%
get_insights(data)
# Out:
# Avg rating = 3.9
# Percentage of users with poor rating = 20.0%

# %%
#Build recommendation Feature
def get_recommendations(data):
    recommendation = []

    for user in data:
        curr_recomm = {}
        curr_recomm["name"] = user["name"]
        
        if(float(user["rating"]) >= 4):
            curr_recomm["brand"] = "Apple"
        else:
            curr_recomm["brand"] = "Samson"

        recommendation.append(curr_recomm)

    return recommendation

# %%
get_recommendations(data)
# Out:
# [{'name': 'Alice', 'brand': 'Apple'},
#  {'name': 'Bob', 'brand': 'Apple'},
#  {'name': 'Charlie', 'brand': 'Samson'},
#  {'name': 'Diana', 'brand': 'Apple'},
#  {'name': 'Eve', 'brand': 'Samson'}]
