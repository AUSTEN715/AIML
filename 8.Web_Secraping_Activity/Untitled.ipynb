# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://www.apnacollege.in/path-player?courseid=prime-ai&unit=696232e64fba1bea4703d3b9Unit"
res = requests.get(URL)

# %%
soup = BeautifulSoup(res.text, "lxml")
# quotes = soup.select("div.quote")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>Home Main</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="apnacollege.in - Start your Placement journey now.
# Explore batches Alpha - Java, Data Structures &amp; algorithms and Delta - Full stack Web Development" name="description"/>
# <meta content="apna college, apna, college, coding, software engineering, alpha, apna college alpha, alpha course, apna college alpha course, apna college delta, delta, delta course, apna college delta course, apnacollege alpha, apnacollege delta, java, dsa, java dsa, data structures, dsa course, placement , internship" name="keywords"/>
# <meta content="Apna College" name="author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@" name="twitter:site"/>
# <meta content="Home Main" name="twitter:title"/>
# <meta content="apnacollege.in - Start your Placement journey now.
# Explore batches Alpha - Java, Data Structures &amp; algorithms and Delta - Full stack Web Development" name="twitter:description"/>
# <meta content="https://lwfiles.mycourse.app/62a6cd5e1e9e2fbf212d608d-public/0f275b1c30123c908cc8491a86d9146a.png" name="twitter:image"/>
# <meta content="https://www.apnacollege.in/" property="og:url"/>
# <meta content="Home Main" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://lwfiles.mycourse.app/62a6cd5e1e9e2fbf212d608d-public/0f275b1c30123c908cc8491a86d9146a.png" property="og:image"/>
# <meta content="apnacollege.in - Start your Placement journey now.
# Explore batches Alpha - Java, Data Structures &amp; algorithms and Delta - Full stack Web Development" property="og:description"/>
# <meta content="Apna College" property="og:site_name"/>
# <meta content="95b4f77799753386e1309a338bfd7394b3bcca30d5038d4062e17cb7f340d8a7" name="csrf-token"/>
# <link href="https://www.apnacollege.in/" rel="canonical"/>
# <link href="https://lwfiles.mycourse.app/62a6cd5e1e9e2fbf212d608d-public/0f275b1c30123c908cc8491a86d9146a.png" rel="icon" type="image/png"/>
# <link href="https://lwfiles.mycourse.app/62a6cd5e1e9e2fbf212d608d-public/0f275b1c30123c908cc8491a86d9146a.png" rel="apple-touch-icon" type="image/png"/>
# <script type="text/javascript">var me=false;var environment='production';var imagePath='https://cdn.mycourse.app/v4.152.0';var server='//www.apnacollege.in/api/';var fileServer='https://api.asia-se1.learnworlds.com/';var api='https://api.asia-se1.learnworlds.com/';var lw_client='62a6cd5e1e9e2fbf212d608d';var serverImg='https://lwfiles.mycourse.app/62a6cd5e1e9e2fbf212d608d-public/';var subscriptionMode=false;var paymentsURL='https://www.apnacollege.in/payment?product_id=';var clientURL='//www.apnacollege.in';var SITENAME='Apna College';var WHITELABEL=true;var WHITELABEL_SETTINGS='{"learn_more_admin_disabled":false,"learn_more_others_disabled":false}';var BILLING='C';var SITE_AFFILIATES={"active":true,"commissionRate":10,"cookieExpiration":30,"maturation":30,"selfRegister":true,"displayAffiliateCustomers":true,"displayAffiliateLeads":true,"products":[{"id":"683198e296dfb0a77f051075","type":"course"},{"id":"67c1a7655319f158d00c5155","type":"course"}],"paymentMethods":["wire","other"],"agreement":"","minAffiliateCommissionStatus":"new","afterLoginNavigation":{"type":"dashboard","url":"","page":{"title":"Home","slug":"home"}},"products-migration-v4":[{"productType":"Course","id":"683198e296dfb0a77f051075","titleId":"sigma-8","title":"Sigma 8.0","price":3,"image":"https:\/\/api.asia-se1.learnworlds.com\/imagefile\/https:\/\/lwfiles.mycourse.app\/62a6cd5e1e9e2fbf212d608d-public\/eef8f63bde4dffea39866dc8d2739af7.jpg?client_id=62a6cd5e1e9e2fbf212d608d&width=400&height=0","status":"paid"},{"productType":"Course","id":"67c1a7655319f158d00c5155","titleId":"sigma-7","title":"Sigma 7.0","price":2,"image":"https:\/\/api.asia-se1.learnworlds.com\/imagefile\/https:\/\/lwfiles.mycourse.app\/62a6cd5e1e9e2fbf212d608d-public\/36f87ff79e2ce6164846b0e0f55094aa.jpg?client_id=62a6cd5e1e9e2fbf212d608d&width=400&height=0","status":"paid"}]};var LWSettings={"deactive_components":{"ebook":false},"components_settings":{"dailynews":{"categories":false},"posts":{"tips":false,"livecode":false}}};var LWClient={"promotions":true,"learning_programs_one_off":true,"learning_programs_subscriptions":true,"learning_programs_navigation_sequential":true,"learning_programs_navigation_with_prerequisites":true,"integrations":true,"advanced_integrations":true,"financial_gateways":true,"theming":true,"coursehub_publishing":true,"pages_templates":true,"pages_builder_starter":true,"pages_builder_advanced_templates":true,"course_unit_completion":true,"course_unit_navigation_sequential":true,"course_unit_navigation":true,"pages_builder":true,"instructors":100,"seat_managers":100,"affiliates":true,"affiliates_partial":true,"question_bank":true,"account_manager":true,"certifications":true,"import_assessment_from_xls":true,"advanced_analytics":true,"free_courses":true,"private_courses":true,"private_enroll":true,"interactive_video":true,"white_label":true,"gamification":true,"includes":true,"admins":true,"ebooks":true,"social":true,"multilanguage":true,"learning_programs_free":true,"learning_programs_private":true,"videouploader":true,"api":true,"webhooks":true,"thank_you_page":true,"after_purchase_partial_settings":true,"after_purchase_settings":true,"pdf_watermark":true,"video_watermark":true,"video_transcript":true,"video_subtitles":true,"video_headings":true,"video_skin":true,"video_elements_basic":true,"video_elements_advanced":true,"video_thumbnail":true,"video_on_click_actions":true,"video_on_show_actions":true,"integration_zoom":true,"integration_webex":true,"integration_google_meet":true,"integration_teams":true,"integration_calendly":true,"integration_hubspot":true,"livesession_multiple_accounts":true,"scorm":true,"graded_scorm":true,"analytics_advanced_queries":true,"analytics_simple_queries":true,"custom_fonts":true,"custom_code_liquid_expressions":true,"mobile_app_submit":true,"file_assignment_course_unit":true,"popups":9223372036854775807,"user_login_permission":true,"site_flavor_export":true,"site_flavor_import":true,"site_templates":9223372036854775807,"report_sche ...
# <script type="text/javascript">var pageState={"id":"62a852db09989a9cb707838a","slug":"home","pageSource":null,"sections":{"section_1697995591336_621":{"sectionType":"section","sectionId":"section_1697995591336_621","styles":{"desktop":{"#section_1697995591336_621":{"paddingTop":"80px"},"#section_1697995591336_621 __DOT__js-learnworlds-overlay":{"display":"none"}}},"anchor":"","videoMediaData":{"params":{"autoplay":true,"mute":true,"loop":false,"popup":false}},"embedMediaData":null,"imageMediaData":{"title":"bg gradient 3","tags":[],"width":1920,"height":1080,"size":36,"name":"\/f068200b0c2e168d3d5f8dd7cddd575e.jpeg","access":"public","created":1684496095.80416,"modified":1684496107.587646,"user":{"username":"Aman Dhattarwal"},"id":"64675edf63739d1b550e7afe","modifiedF":"2023-05-19 14:35:07","link":"https:\/\/lwfiles.mycourse.app\/62a6cd5e1e9e2fbf212d608d-public\/f068200b0c2e168d3d5f8dd7cddd575e.jpeg","link_small":"https:\/\/api.us-e2.learnworlds.com\/imagefile\/https:\/\/lwfiles.mycourse.app\/62a6cd5e1e9e2fbf212d608d-public\/f068200b0c2e168d3d5f8dd7cddd575e.jpeg?client_id=62a6cd5e1e9e2fbf212d608d&width=350&height=0","uploadFromUnsplash":false},"svgMediaData":null,"selectedMedia":"Image","version":"v1","responsiveHeightClass":{"desktop":"","tablet-portrait":"","tablet-landscape":"","smartphone-portrait":"","smartphone-landscape":""},"responsiveAlignmentClass":{"desktop":"","tablet-portrait":"","tablet-landscape":"","smartphone-portrait":"","smartphone-landscape":""},"itemVisibilitySettings":{"value":"","data":null},"itemVisibilityStartTime":null,"itemVisibilityEndTime":null,"effectName":"none","effects":null,"effectTrigger":"scrollEffects","hideSection":false,"persistence":{"enabled":false,"linkedSectionId":null}},"section_1655917358400_387":{"sectionType":"section","sectionId":"section_1655917358400_387","styles":{"desktop":{"#section_1655917358400_387":{"backgroundColor":"#505ba0"},"#section_1655917358400_387 __DOT__on-bottom":[],"#section_1655917358400_387 __DOT__on-top":[]}},"anchor":"","videoMediaData":{"params":{"autoplay":true,"mute":true,"loop":false,"popup":false}},"embedMediaData":null,"imageMediaData":{"title":"REGRET","tags":[],"width":1920,"height":1080,"size":126,"name":"\/b99ce63825f224170fba18171ed8ca0d.jpeg","access":"public","created":1655902781.393443,"modified":1655902781.393443,"user":{"username":"Aman Dhattarwal"},"id":"62b3123d5ec51378cf0467d3","link":"https:\/\/lwfiles.mycourse.app\/62a6cd5e1e9e2fbf212d608d-public\/b99ce63825f224170fba18171ed8ca0d.jpeg","link_small":"https:\/\/api.us-e2.learnworlds.com\/imagefile\/https:\/\/lwfiles.mycourse.app\/62a6cd5e1e9e2fbf212d608d-public\/b99ce63825f224170fba18171ed8ca0d.jpeg?client_id=62a6cd5e1e9e2fbf212d608d&width=350&height=0","modifiedF":"2022-06-22 15:59:41"},"svgMediaData":null,"selectedMedia":"Color","version":"v1","responsiveHeightClass":{"desktop":"","tablet-portrait":"","tablet-landscape":"","smartphone-portrait":"","smartphone-landscape":""},"responsiveAlignmentClass":{"desktop":"","tablet-portrait":"","tablet-landscape":"","smartphone-portrait":"","smartphone-landscape":""},"itemVisibilitySettings":null,"itemVisibilityStartTime":null,"itemVisibilityEndTime":null,"hideSection":false,"persistence":{"enabled":false,"linkedSectionId":null}},"section_1655664995743_469":{"sectionType":"section","sectionId":"section_1655664995743_469","styles":{"desktop":{"#section_1655664995743_469":{"marginTop":"0px"}}},"anchor":"","videoMediaData":{"params":{"autoplay":true,"mute":true,"loop":false,"popup":false}},"embedMediaData":null,"imageMediaData":null,"svgMediaData":null,"selectedMedia":null,"version":"v1","responsiveHeightClass":{"desktop":"","tablet-portrait":"","tablet-landscape":"","smartphone-portrait":"","smartphone-landscape":""},"responsiveAlignmentClass":{"desktop":"","tablet-portrait":"","tablet-landscape":"","smartphone-portrait":"","smartphone-landscape":""},"itemVisibilitySettings":null,"itemVisibilityStartTime":null,"itemVisibilityEndTime":null,"hideSect ...
# <script type="text/javascript">var pagePopups=[];</script>
# <script type="text/javascript">var pageGroups=["external pages"];</script>
# <script type="text/javascript">var globalTopbar={"logged-in":{"sectionId":"section_1564405797906_0","components":{"component_1593094758262_3":{"componentType":"hamburger-menu","componentId":"component_1593094758262_3","styles":null,"animationData":null,"itemVisibilitySettings":null,"version":"v1"},"component_11111111111_0":{"componentType":"navigation-menu","componentId":"component_11111111111_0","template":"navigationMenu1","styles":{"desktop":{"#component_11111111111_0 __DOT__lw-topbar-option-link":{"font-family":"Lato"},"#component_11111111111_0 __DOT__lw-topbar-option-link:not(__DOT__button-like)":{"color":"#323951"}}},"activeLinkDisplay":"1","menuLinksAppearance":"textOnly","menuLinksSize":"","items":[{"label":"New SigmaX","addControls":true,"appearance":"roundedSolid","editControls":true,"subItems":[],"isOpen":false,"linkData":{"linkType":"courselink","linkTo":"sigmax","linkToExtra":"internalPage","linkOpen":"default","href":"\/course\/sigmax"},"inHamburger":true,"id":"menuItem_1701978665536_339","borderRadius":0.16},{"label":"New Courses","addControls":true,"appearance":"","editControls":true,"subItems":[{"label":"SigmaX (AI-Powered Placement Prep)","inHamburger":true,"editControls":true,"linkData":{"linkType":"courselink","linkTo":"sigmax","linkToExtra":"internalPage","linkOpen":"default","href":"\/course\/sigmax"},"appearance":"","id":"menuSubItem_1740777085618_340","borderRadius":0},{"label":"Alpha Plus (Complete DSA)","inHamburger":true,"editControls":true,"linkData":{"linkType":"pagelink","linkTo":"alpha-plus-dsa","linkToExtra":"","linkOpen":"default","href":"\/alpha-plus-dsa"},"appearance":"","id":"menuSubItem_1715760507382_339","borderRadius":0},{"label":"Delta (Complete Web Development)","inHamburger":true,"editControls":true,"linkData":{"linkType":"courselink","linkTo":"delta-9","linkToExtra":"internalPage","linkOpen":"default","href":"\/course\/delta-9"},"appearance":"","id":"menuSubItem_1684698292665_362","borderRadius":0},{"label":"Sigma 12 (Complete Placement Prep)","inHamburger":true,"editControls":true,"linkData":{"linkType":"courselink","linkTo":"sigma-12","linkToExtra":"internalPage","linkOpen":"default","href":"\/course\/sigma-12"},"appearance":"","id":"menuSubItem_1714504398037_420","borderRadius":0},{"label":"Prime 2.0 (Complete AI\/ML Batch)","inHamburger":true,"editControls":true,"linkData":{"linkType":"courselink","linkTo":"prime-2","linkToExtra":"internalPage","linkOpen":"default","href":"\/course\/prime-2"},"appearance":"","id":"menuSubItem_1761258273197_624","borderRadius":0}],"isOpen":false,"linkData":[],"inHamburger":true,"id":"menuItem_1684698282878_361"},{"label":"Our Results","addControls":true,"appearance":"textOnlyAccent1","editControls":true,"subItems":[],"isOpen":false,"linkData":{"linkType":"weblink","linkTo":"https:\/\/results.apnacollege.in\/","linkToExtra":"","linkOpen":"new","href":"https:\/\/results.apnacollege.in\/"},"inHamburger":true,"id":"menuItem_1748115899737_371","borderRadius":0},{"label":"DSA Sheet","addControls":true,"appearance":"","editControls":true,"subItems":[],"isOpen":false,"linkData":{"linkType":"weblink","linkTo":"https:\/\/dsa.apnacollege.in\/","linkToExtra":"","linkOpen":"new","href":"https:\/\/dsa.apnacollege.in\/"},"inHamburger":true,"id":"menuItem_1656083386113_333","borderRadius":0},{"id":"menuItem10","inHamburger":true,"label":"My Batch","linkData":{"linkType":"pagelink","linkTo":"start","linkToExtra":"","linkOpen":"default","href":"\/start"},"subItems":[],"borderRadius":0},{"id":"menuItem12","appearance":"","label":"Sign out","linkData":{"linkType":"signout","href":"\/signout"},"subItems":[],"borderRadius":0.5}],"hoverEnabled":true,"hoverEffect":"","fontWeight":700,"fontSize":1.6,"letterSpacing":0,"animationData":null,"itemVisibilitySettings":null}},"sticksOnScroll":true,"transparentBackground":"","hidden":"","content":"<section class=\"js-learnworlds-section learnworlds-section lw-topbar lw-body-bg stretched-bg js-change-image-node sticky-topbar\" data ...
# <script type="text/javascript">var globalFooter={"logged-in":{"sectionId":"section_123412341234_0","content":"<section class=\"js-learnworlds-section learnworlds-section lw-footer footer1 stretched-bg learnworlds-size-normal learnworlds-align-left js-change-image-node lw-body-bg\" data-section-id=\"tpl44\" data-magic=\"background-image\" id=\"section_123412341234_0\">\n\n    <div class=\"js-video-wrapper\"><\/div>\n    <div class=\"learnworlds-section-overlay lw-light-bg js-learnworlds-overlay\" style=\"display: none;\"><\/div>\n    <div class=\"learnworlds-section-content js-learnworlds-section-content wide\">\n\n        <div class=\"lw-cols align-items-stretch one-row one-row-tl multiple-rows-tp multiple-rows-sl multiple-rows-sp js-same-content-wrapper\" data-node-type=\"columnWrapper\" id=\"el_1600798408557_113\">\n\n            <div class=\"col mb-4rem non-flexible footer-col flex-item va-fs span_3_of_12 span_3_of_12-tl span_6_of_12-tp span_6_of_12-sl span_12_of_12-sp js-lw-flexible-wrapper js-same-content-child\" data-node-type=\"column\" id=\"el_1591888215403_349\">\n                <img src=\"https:\/\/lwfiles.mycourse.app\/62a6cd5e1e9e2fbf212d608d-public\/6efdd5e7f0d663cf231d0f2040be0a1e.png\" class=\"lw-widget-in learnworlds-image learnworlds-element js-change-image-node\" data-node-type=\"image\" data-element-id=\"image\" id=\"el_1655312953245_326\">\n                <a class=\"js-linked-node\" href=\"\/home\"><div class=\"lw-widget-in learnworlds-main-text learnworlds-element cursor-pointer learnworlds-main-text-normal\" data-element-id=\"heading4Small\" data-node-type=\"text\" id=\"el_1591888215408_357\">Where education meets real-world needs.<\/div><\/a>\n            <\/div>\n\n            <div class=\"col mb-4rem non-flexible footer-col flex-item va-fs span_3_of_12 span_3_of_12-tl span_6_of_12-tp span_6_of_12-sl span_12_of_12-sp js-lw-flexible-wrapper js-same-content-child\" data-node-type=\"column\" id=\"el_1591888215405_352\">\n\n                <a class=\"js-linked-node learnworlds-heading3\" href=\"\/home\"><h3 class=\"learnworlds-heading3 learnworlds-element learnworlds-heading3-small cursor-pointer\" data-node-type=\"text\" id=\"el_1591888215410_360\">Helpful Links<\/h3><\/a>\n                <ul class=\"lw-footer-links lw-cols no-gutter multiple-rows multiple-rows-tl multiple-rows-tp multiple-rows-sl multiple-rows-sp flex-start js-same-content-wrapper oneItem-per-row\" data-node-type=\"listWrapper\" id=\"el_1600798408566_114\">\n                    \n                    <li class=\"col no-padding flex-item with-flexible-parts non-flexible js-lw-flexible-wrapper js-same-content-child\" data-node-type=\"listItem\" id=\"el_1591888215418_373\">\n                        <span data-node-type=\"icon\" class=\"learnworlds-main-text-small flexible-part learnworlds-icon lw-brand-text fas fa-angle-right\" id=\"el_1598006564429_43\"><\/span>\n                        <a class=\"js-linked-node\" href=\"\/all-courses\"><div class=\"flexible-part learnworlds-main-text learnworlds-main-text-small learnworlds-element cursor-pointer\" data-node-type=\"text\" id=\"el_1591888215414_366\">\n                            Courses\n                        <\/div><\/a>\n                    <\/li>\n                    \n                    \n                    \n                    <li class=\"col no-padding flex-item with-flexible-parts non-flexible js-lw-flexible-wrapper js-same-content-child\" data-node-type=\"listItem\" id=\"el_1591888215409_358\">\n                        \n                        <a class=\"js-linked-node\" href=\"\/contact\"><\/a>\n                    <\/li>\n                    <li class=\"col no-padding flex-item with-flexible-parts non-flexible js-lw-flexible-wrapper js-same-content-child\" data-node-type=\"listItem\" id=\"el_1599582987293_42\">\n                        <span data-node-type=\"icon\" class=\"learnworlds-main-text-small flexible-part learnworlds-icon lw-brand-text fas fa-angle-right\" id=\"el ...
# <script type="text/javascript">var LINK_TITLEID_TO_SLUG={"course":{"sigmax":"sigmax","sigma-12":"sigma-12","delta-9":"delta-9","prime-2":"prime-2"}};</script>
# <link href="https://cdn.mycourse.app/v4.152.0/_cdnAssets/webpack/99970.a017e2b009f66d631a1c.css" media="print" onload="this.media='all'" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.mycourse.app/v4.152.0/_cdnAssets/webpack/32206.1cf507216ed8bec2daa5.css" media="print" onload="this.media='all'" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.mycourse.app/v4.152.0/_cdnAssets/webpack/39758.011f70221628728f56b3.css" media="print" onload="this.media='all'" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.mycourse.app/v4.152.0/_cdnAssets/webpack/18301.21561e7cc90dd46d7805.css" media="print" onload="this.media='all'" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.mycourse.app/v4.152.0/_cdnAssets/webpack/_components/pb-preview/pb-preview.bb8acc4f7607daec88c6.css" media="print" onload="this.media='all'" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.mycourse.app/v4.152.0/_cdnAssets/webpack/60079.8ac8c01ceb79295787bd.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.mycourse.app/v4.152.0/_cdnAssets/webpack/pages.bfb629e1104a742cdf4f.css" rel="stylesheet" type="text/css"/>
# <script src="https://cdn.mycourse.app/v4.152.0/_cdnAssets/webfont/webfont.js"></script><script>
#             (function(){
#               var fontFamilies = ["Barlow:300,300i,400,400i,700,700i,800,800i","Inter:300,300i,400,400i,700,700i,800,800i","Lato:300,300i,400,400i,700,700i,800,800i","Merriweather:300,300i,400,400i,700,700i,800,800i",'&display=swap'];
#               var customFontFamilies = ["Satoshi-Medium","Satoshi-Bold","Satoshi-Regular"];
#
#
#               // For when WebFont has not loaded
#               if (typeof WebFont === "undefined" || typeof WebFont.load === "undefined") {
#                     console.log("undefined webfont");
#               } else {
#                     var config = {};
#                     if(fontFamilies.length){
#                         config["google"] = { families: fontFamilies }
#                     }
#                     if(customFontFamilies.length){
#                         config["custom"] = { families: customFontFamilies }
#                     }
#                     WebFont.load( config );
#               }
#             })();
#
#             </script>
# <link href="https://releases.transloadit.com/uppy/v2.10.0/uppy.min.css" media="print" onload="this.media='all'" rel="stylesheet" type="text/css"/>
# <script data-cookieconsent="ignore" src="https://cdn.mycourse.app/v4.152.0/_cdnAssets/jquery/jquery.js"></script>
# <script data-cookieconsent="ignore" src="https://cdn.mycourse.app/v4.152.0/_cdnAssets/jquery/jquery-migrate-1.4.1.min.js"></script>
# <script data-cookieconsent="ignore" src="https://cdn.mycourse.app/v4.152.0/_cdnAssets/jquery/jquery-migrate-3.4.1.min.js"></script>
# <style>
#                 section.learnworlds-section:nth-child(n+4) [data-node-type="framedImage"]:not(.in-view),
#                 section.learnworlds-section:nth-child(n+4) [data-node-type="screen"]:not(.in-view) .js-change-image-node {
#                     background-image: url(...) !important;
#                 }
#             </style>
# <style>.* {font-family: "Barlow"; }.learnworlds-main-text {font-family: "Inter"; }.learnworlds-heading {font-family: "Barlow"; }.learnworlds-subheading {font-family: "Barlow"; }.learnworlds-heading3 {font-family: "Barlow"; }.learnworlds-heading4 {font-family: "Barlow"; }.learnworlds-button {font-family: "Barlow"; }.learnworlds-input {font-family: "Barlow"; }.learnworlds-heading-large {font-size: 6rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.2; text-transform: uppercase; font-family: "Barlow"; }.learnworlds-heading-normal {font-size: 5rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.2; text-transform: uppercase; font-family: "Barlow"; }.learnworlds-heading-small {font-size: 2.9rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.2; text-transform: uppercase; font-family: "Barlow"; }.learnworlds-subheading-large {font-size: 5rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.2; text-transform: uppercase; font-family: "Barlow"; }.learnworlds-subheading-normal {font-size: 2.9rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.2; text-transform: uppercase; font-family: "Barlow"; }.learnworlds-subheading-small {font-size: 2.1rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.2; text-transform: uppercase; font-family: "Barlow"; }.learnworlds-heading3-large {font-size: 2.9rem; font-weight: bold; letter-spacing: 0rem; line-height: 1.4; text-transform: uppercase; font-family: "Barlow"; }.learnworlds-heading3-normal {font-size: 2.1rem; font-weight: bold; letter-spacing: 0rem; line-height: 1.4; text-transform: uppercase; font-family: "Barlow"; }.learnworlds-heading3-small {font-size: 1.8rem; font-weight: bold; letter-spacing: 0rem; line-height: 1.4; text-transform: uppercase; font-family: "Barlow"; }.learnworlds-heading4-large {font-size: 2.1rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.4; text-transform: uppercase; font-family: "Barlow"; }.learnworlds-heading4-normal {font-size: 1.8rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.4; text-transform: uppercase; font-family: "Barlow"; }.learnworlds-heading4-small {font-size: 1.4rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.4; text-transform: uppercase; font-family: "Barlow"; }.learnworlds-main-text-huge {font-size: 9rem; font-weight: 300; letter-spacing: 0rem; line-height: 1; text-transform: none; font-family: "Inter"; }.learnworlds-main-text-very-large {font-size: 5rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.55; text-transform: none; font-family: "Inter"; }.learnworlds-main-text-large {font-size: 2.2rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.55; text-transform: none; font-family: "Inter"; }.learnworlds-main-text-normal {font-size: 1.8rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.55; text-transform: none; font-family: "Inter"; }.learnworlds-main-text-small {font-size: 1.6rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.55; text-transform: none; font-family: "Inter"; }.learnworlds-main-text-very-small {font-size: 1.4rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.55; text-transform: none; font-family: "Inter"; }.learnworlds-main-text-tiny {font-size: 1.2rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.55; text-transform: none; font-family: "Inter"; }.learnworlds-quote-text {font-family: "Inter"; font-size: 3.2rem; font-weight: normal; letter-spacing: 0rem; line-height: 1.55; text-transform: none; }.learnworlds-overline-text {font-family: "Inter"; font-size: 1.4rem; font-weight: bold; letter-spacing: 0.01rem; line-height: 1.55; text-transform: uppercase; }.learnworlds-size-small {padding-bottom: 70px; padding-top: 70px; }.learnworlds-size-normal {padding-bottom: 120px; padding-top: 120px; }.learnworlds-size-large {padding-bottom: 180px; padding-top: 180px; }.learnworlds-size-extra-large {padding-bottom: 220px; padding-top: 220px; }.learnworlds-button-large {font-family: "I ...
# <style>@font-face {
#     font-family: 'Satoshi-Medium';
#     font-display: swap;
#     src: url('https://lwfiles.mycourse.app/62a6cd5e1e9e2fbf212d608d-public/fonts/0884ea5fc6559060bce41ca3785b0f2d.ttf') format('truetype');
# }@font-face {
#     font-family: 'Satoshi-Bold';
#     font-display: swap;
#     src: url('https://lwfiles.mycourse.app/62a6cd5e1e9e2fbf212d608d-public/fonts/b7721e9261bac262f7aa95ba0da5fa1a.ttf') format('truetype');
# }@font-face {
#     font-family: 'Satoshi-Regular';
#     font-display: swap;
#     src: url('https://lwfiles.mycourse.app/62a6cd5e1e9e2fbf212d608d-public/fonts/469f1d4dd7aed64957123ae3f7031006.ttf') format('truetype');
# }</style>
# <script>
#             window.googleAnalyticsEventsEnabled = {"view_item":true,"add_to_cart":true,"begin_checkout":true};
#             </script>
# <script> window.dataLayer = window.dataLayer || [];
#                 function gtag() {
#                         dataLayer.push(arguments);
#                 }
#                 gtag('consent', 'default', {"ad_personalization":"granted","ad_storage":"granted","ad_user_data":"granted","analytics_storage":"granted","functionality_storage":"granted","personalization_storage":"granted","security_storage":"granted"})
#                </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-VPHPY6NJ60" type="text/javascript"></script>
# <script type="text/javascript">
#                 window.dataLayer = window.dataLayer || [];
#                 function gtag(){
#                     dataLayer.push(arguments);
#                 }
#
#                 gtag('js', new Date());
#
#                 gtag('config', 'G-VPHPY6NJ60' );
#                 gtag('get', 'G-VPHPY6NJ60', 'client_id', client_id => {
#                     window.GTAG_CLIENT_ID = client_id;
#                 });
#
#                 </script>
# <meta content="kqOq_hoYvvPxJmyoaDSedq1NNcmWQJb6sLBACLKI6GI" name="google-site-verification"/>
# <script>
#             window.googleTagManagerEventsEnabled = {"view_item":true,"add_to_cart":true,"begin_checkout":true};
#             </script>
# <script> window.googleTagManager = window.googleTagManager || [];
#                 function gtagGTM() {
#                         googleTagManager.push(arguments);
#                 }
#                 gtagGTM('consent', 'default', {"ad_personalization":"granted","ad_storage":"granted","ad_user_data":"granted","analytics_storage":"granted","functionality_storage":"granted","personalization_storage":"granted","security_storage":"granted"})
#                </script><!-- Google Tag Manager -->
# <script type="text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#             })(window,document,'script','googleTagManager','GTM-WM5R98Q2');</script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript">
#                 if(typeof googleTagManager != 'undefined'){
#                     googleTagManager.push({'pageTitle': 'Home'});
#                 }
#             </script>
# <style>:root {--font-size-desktop: 10px;--font-size-tablet-portrait: 9px;--font-size-smartphone-portrait: 8px;--font-size-tablet-landscape: 10px;--font-size-smartphone-landscape: 8px;}</style>
# <style>#section_1697995591336_621 { padding-top:80px; } #section_1697995591336_621 .js-learnworlds-overlay { display:none; } #el_1697995591336_611 { padding-top:0px;margin-top:0px;margin-bottom:-20px; } #el_1697995591336_614 { opacity:1;font-family:"Satoshi-Medium";margin-top:-30px; } #el_1697995591336_615 { margin-top:20px;font-family:"Satoshi-Medium"; } #el_1697995591336_618 { border-top-left-radius:4px;border-top-right-radius:4px;border-bottom-left-radius:4px;border-bottom-right-radius:4px;background-color:#364bc5; } #section_1655917358400_387 { background-color:#505ba0; } #section_1655917358400_387 .on-bottom {  } #section_1655917358400_387 .on-top {  } #el_1655917953102_458 { font-family:"Satoshi-Medium"; } #el_1655925815735_1263 { font-size:24px; } #el_1655925815735_1264 { font-family:"Satoshi-Regular"; } #el_1655925815735_1265 { font-family:"Satoshi-Medium"; } #el_1655925815735_1268 { font-size:24px; } #el_1655925815735_1269 { font-family:"Satoshi-Regular"; } #el_1655925815735_1270 { font-family:"Satoshi-Medium"; } #el_1655925815735_1273 { font-size:24px; } #el_1655925815735_1274 { font-family:"Satoshi-Regular"; } #el_1655925815735_1275 { font-family:"Satoshi-Medium"; } #section_1655664995743_469 { margin-top:0px; } #el_1658182735719_327 { font-family:"Satoshi-Regular"; } #el_1656180742513_953 { font-family:"Satoshi-Bold"; } #el_1655665499560_569 { text-shadow:0px 0px 0px rgba(50, 57, 81, 1.0);font-family:"Satoshi-Medium"; } #el_1655665720072_636 { box-shadow:0px 3px 7px 0px rgba(0, 0, 0, 0.2);border-top-left-radius:4px;border-top-right-radius:4px;border-bottom-left-radius:4px;border-bottom-right-radius:4px;background-color:#364bc5; } #section_1697997438894_1208 .on-top {  } #section_1697997438894_1208 {  } #el_1697997438894_1167 { font-family:"Satoshi-Medium"; } #el_1697997438894_1169 { margin-top:0px; } #el_1697997438894_1195 { margin-top:0px; } #el_1697997438894_1170 { margin-top:-15px;font-family:"Satoshi-Regular";opacity:0.7; } #el_1697997438894_1183 { width:120px;height:auto; } #el_1697997438894_1184 { width:120px;height:auto; } #el_1697997438894_1185 { width:140px;height:auto; } #el_1697997438894_1186 { width:100px;height:auto; } #el_1697997438894_1187 { width:120px;height:auto; } #el_1697997438894_1188 { width:120px;height:auto; } #el_1697997438894_1189 { width:142px;height:auto; } #el_1697997438894_1190 { width:100px;height:auto; } #el_1697997438894_1191 { width:100px;height:auto; } #el_1697997438894_1192 { width:120px;height:auto; } #el_1697997438894_1193 { width:100px;height:auto; } #el_1697997438894_1194 { width:120px;height:auto; } #el_1697997438894_1202 { width:142px;height:auto; } #el_1697997438894_1203 { width:100px;height:auto; } #el_1697997438894_1204 { width:140px;height:auto; } #el_1697997438894_1205 { width:120px;height:auto; } #el_1697997438894_1206 { width:100px;height:auto; } #el_1697997438894_1207 { width:120px;height:auto; } #section_1697985071847_1108 { border-top-style:solid;border-right-style:solid;border-bottom-style:solid;border-left-style:solid;border-bottom-width:0px;border-left-width:0px;border-right-width:0px;border-color:#000000;border-top-width:1px; } #el_1697985071847_1063 { margin-bottom:35px;font-family:"Satoshi-Medium";margin-top:-60px; } #el_1697985071847_1065 { margin-top:30px; } #el_1697985071847_1066 { margin-top:30px; } #el_1697985071847_1067 { margin-top:30px; } #el_1697985071847_1068 { margin-top:30px; } #el_1697985071847_1069 { margin-top:30px; } #el_1697985071847_1070 { margin-top:30px; } #el_1697985071847_1071 { margin-top:30px; } #el_1697985071847_1073 { background-color:rgba(0, 0, 0, 0.0); } #el_1697985071847_1074 { border-top-left-radius:16px;border-top-right-radius:16px;border-bottom-left-radius:16px;border-bottom-right-radius:16px;background-color:rgba(0, 0, 0, 0.0); } #el_1697985071847_1075 { background-color:rgba(0, 0, 0, 0.0); } #el_1697985071847_1076 { border-top-left-radius:16px;border-top-right-radius:16px;border-bottom-left-radius:16px;border-bottom-right-ra ...
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WM5R98Q2');</script>
# <!-- End Google Tag Manager -->
# <style> #section_1564405816535_1 { padding-top:10px;padding-bottom:10px; } #component_222222222222_0 .lw-topbar-option-link { font-family:Lato; } #component_222222222222_0 .lw-topbar-option-link:not(.button-like) { color:#1A2930; } #component_222222222222_0 { margin-left:-20px; } #el_1593094758324_16 { height:auto;width:99px; }  @media (max-width: 500px) { #section_1564405816535_1 { padding-top:0px;padding-bottom:0px; }  } </style>
# <style> #section_123412341234_0 {  } #el_1655312953245_326 { width:100px;height:auto; } #el_1686088319546_841 { font-size:18px;margin-right:4px; } #el_1686088319546_841 #el_1686088374257_880 { width:18px; } #el_1686088325086_852 { font-size:18px;margin-right:4px; } #el_1706632766602_384 { font-size:18px;margin-right:4px; } #el_1693344616232_376 { font-size:18px;margin-right:4px; }  </style>
# </head>
# <body class="slug-home active-sitetemplate lw-page" style="--font-family-main-text: Inter">
# <div id="pageContainer">
# <div class="page-content normal" id="pageContent" ref="pageContent">
# <section class="js-learnworlds-section learnworlds-section lw-topbar lw-body-bg stretched-bg js-change-image-node transparent-onStart sticky-topbar" data-magic="background-image" data-section-id="topbar1" id="section_1564405816535_1">
# <div class="lw-h-row js-same-content-wrapper">
# <div class="learnworlds-section-content js-learnworlds-section-content wide">
# <div class="lw-cols js-same-content-wrapper" data-node-type="columnWrapper" id="el_1594985834127_1">
# <div class="lw-topbar-logo-col col flex-item with-flexible-parts ai-s flex-none justify-content-flex-start js-same-content-child" data-node-type="column" id="el_1593094758321_15">
# <div class="lw-topbar-logo-wrapper flex-item with-flexible-parts va-c">
# <a class="js-linked-node" href="/home"><img class="learnworlds-element lw-logo js-change-image-node cursor-pointer" data-magic="image" data-node-type="image" id="el_1593094758324_16" src="https://lwfiles.mycourse.app/62a6cd5e1e9e2fbf212d608d-public/87c40f6213de38546841280fb345d40f.png"/></a>
# </div>
# </div>
# <div class="hide-tp hide-sl hide-sp col flex-item with-flexible-parts ai-s flex-1 js-same-content-child" data-node-type="column" id="el_1593094758327_17"></div>
# <div class="hide-tp hide-sl hide-sp col flex-item with-flexible-parts ai-s flex-1 justify-content-flex-end js-same-content-child" data-node-type="column" id="el_1593094758407_18">
# <div class="flex-item with-flexible-parts va-c">
# <div class="lw-topbar-menu-wrapper flexible-cnt-wrapper js-lw-flexible-wrapper js-component link-distance-normal" data-node-type="navigation-menu" data-random-render-menu-component="menu_component_1785697810630_399" id="component_222222222222_0">
# <nav class="lw-topbar-menu with-hover">
# <ul class="lw-topbar-options with-flexible-parts align-items-center">
# <li class="lw-topbar-option">
# <a class="lw-topbar-option-link learnworlds-main-text-normal js-menu-item learnworlds-button-solid-brand button-like js-linked-node" data-interactive-link-type="courselink" data-interactive-link-var1="sigmax" data-interactive-link-var2="internalPage" data-interactive-link-window="default" href="/course/sigmax" id="menuItem_1701978726001_367" style="font-size:1.6rem;border-radius:4.8px;font-weight:700;">
# <span class="lw-topbar-option-link-lbl nowrap">New SigmaX</span>
# </a>
# </li>
# <li class="lw-topbar-option">
# <div class="lw-topbar-option-link learnworlds-main-text-normal js-menu-item lw-brand-text text-only js-with-submenu-list with-submenu" id="menuItem_1684698130873_351" style="font-size:1.6rem;font-weight:700;">
# <span class="lw-topbar-option-link-lbl nowrap">New Courses</span>
# </div>
# <ul class="lw-topbar-submenu js-submenu-list" style="background-color: rgb(255, 255, 255);">
# <li class="lw-topbar-submenu-item js-submenu-item">
# <a class="lw-topbar-option-link learnworlds-main-text-normal lw-brand-text text-only js-linked-node" data-interactive-link-type="courselink" data-interactive-link-var1="sigmax" data-interactive-link-var2="internalPage" data-interactive-link-window="default" href="/course/sigmax" id="menuSubItem_1740777145676_356" style="font-size:1.6rem;font-weight:700;">
# 											SigmaX (AI-Powered Placement Prep)
#
# 										</a>
# </li>
# <li class="lw-topbar-submenu-item js-submenu-item">
# <a class="lw-topbar-option-link learnworlds-main-text-normal lw-brand-text text-only js-linked-node" data-interactive-link-type="pagelink" data-interactive-link-var1="alpha-plus-dsa" data-interactive-link-var2="" data-interactive-link-window="default" href="/alpha-plus-dsa" id="menuSubItem_1728757127119_357" style="font-size:1.6rem;font-weight:700;">
# 											Alpha Plus (Complete DSA)
#
# 										</a>
# </li>
# <li class="lw-topbar-submenu-item js-submenu-item">
# <a class="lw-topbar-option-link learnworlds-main-text-normal lw-brand-text text-only js-linked-node" data-interactive-link-type="courselink" data-interactive-link-var1="sigma-12" data-interactive-link-var2="internalPage" data-interactive-link-window="default" href="/course/sigma-12" id="menuSubItem_1714504449644_447" style="font-size:1.6rem;font-weight:700;">
# 											Sigma 12 (Complete Placement Prep)
#
# 										</a>
# </li>
# <li class="lw-topbar-submenu-item js-submenu-item">
# <a class="lw-topbar-option-link learnworlds-main-text-normal lw-brand-text text-only js-linked-node" data-interactive-link-type="courselink" data-interactive-link-var1="delta-9" data-interactive-link-var2="internalPage" data-interactive-link-window="default" href="/course/delta-9" id="menuSubItem_1684698150792_352" style="font-size:1.6rem;font-weight:700;">
# 											Delta (Complete Web Development)
#
# 										</a>
# </li>
# <li class="lw-topbar-submenu-item js-submenu-item">
# <a class="lw-topbar-option-link learnworlds-main-text-normal lw-brand-text text-only js-linked-node" data-interactive-link-type="courselink" data-interactive-link-var1="prime-2" data-interactive-link-var2="internalPage" data-interactive-link-window="default" href="/course/prime-2" id="menuSubItem_1761258331473_642" style="font-size:1.6rem;font-weight:700;">
# 											Prime 2.0 (Complete AI/ML Batch)
#
# 										</a>
# </li>
# </ul>
# </li>
# <li class="lw-topbar-option">
# <a class="lw-topbar-option-link learnworlds-main-text-normal js-menu-item lw-brand-accent1-text text-only js-linked-node" data-interactive-link-type="weblink" data-interactive-link-var1="https://results.apnacollege.in/" data-interactive-link-var2="" data-interactive-link-window="new" href="https://results.apnacollege.in/" id="menuItem_1748115652260_338" style="font-size:1.6rem;font-weight:700;" target="_blank">
# <span class="lw-topbar-option-link-lbl nowrap">Our Results</span>
# </a>
# </li>
# <li class="lw-topbar-option">
# <a class="lw-topbar-option-link learnworlds-main-text-normal js-menu-item lw-brand-text text-only js-linked-node" data-interactive-link-type="weblink" data-interactive-link-var1="https://dsa.apnacollege.in/" data-interactive-link-var2="" data-interactive-link-window="new" href="https://dsa.apnacollege.in/" id="menuItem6" style="font-size:1.6rem;font-weight:700;" target="_blank">
# <span class="lw-topbar-option-link-lbl nowrap">DSA Sheet</span>
# </a>
# </li>
# <li class="lw-topbar-option">
# <a class="lw-topbar-option-link learnworlds-main-text-normal js-menu-item lw-brand-accent1-text text-only js-linked-node" data-interactive-link-type="openformslink" data-interactive-link-var1="signin" data-interactive-link-var2="" data-interactive-link-window="default" href="javascript:void(0)" id="menuItem5" style="font-size:1.6rem;font-weight:700;">
# <span class="lw-topbar-option-link-lbl nowrap">Log in</span>
# </a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="js-lw-topbar-hamburger-wrapper js-component bgcolor-inherit" data-node-type="hamburger-menu" id="component_1593094758256_2"></div>
# </div>
# </section>
# <section class="js-learnworlds-section learnworlds-section stretched-bg learnworlds-size-normal learnworlds-align-left js-change-image-node lw-body-bg" data-magic="background-image" data-section-id="tpl23" id="section_1697995591336_621" style='background-image: url("https://lwfiles.mycourse.app/62a6cd5e1e9e2fbf212d608d-public/f068200b0c2e168d3d5f8dd7cddd575e.jpeg");'><div class="js-video-wrapper" style="display: none;"></div>
# <div class="learnworlds-section-overlay lw-dark-bg js-learnworlds-overlay" style=""></div>
# <div class="learnworlds-section-content js-learnworlds-section-content wide" id="history_1697995510148_565">
# <div class="lw-cols one-row one-row-tl multiple-rows-tp multiple-rows-sl multiple-rows-sp main align-items-stretch js-same-content-wrapper" data-node-type="columnWrapper" id="el_1697995591336_611">
# <div class="col span_6_of_12 span_6_of_12-tl span_12_of_12-tp mb-4rem-tp span_12_of_12-sl mb-4rem-sl span_12_of_12-sp mb-4rem-sp flex-item va-c js-lw-flexible-wrapper js-same-content-child" data-node-type="column" id="el_1697995591336_612">
# <div class="lw-widget-in learnworlds-quote-text learnworlds-element" data-element-id="heading2Normal" data-magic="title" data-node-type="text" id="el_1697995591336_614"><strong>Learn &amp; become the <span style="color: rgb(54, 75, 197);"><br/>Top 1% software developer</span></strong></div><div class="lw-widget-in learnworlds-main-text learnworlds-element learnworlds-main-text-large none" data-element-id="typed2" data-node-type="typed" id="el_1697995591336_615">Alpha Plus - DSA (Java/C++) | Delta - Web Development | SigmaX - DSA + AI Full Stack Web Development + Quant-Aptitude</div>
# <div class="lw-widget-in learnworlds-button-wrapper learnworlds-element js-same-content-wrapper" data-element-id="solidNormalBrandButton" data-node-type="buttonWrapper" id="el_1697995591336_617">
# <a class="js-linked-node" href="/course/sigmax"><button class="learnworlds-button learnworlds-button-normal learnworlds-element js-same-content-child has-icon-back cursor-pointer learnworlds-button-solid-brand" data-node-type="button" id="el_1697995591336_618"><span class="learnworlds-icon fas fa-angle-right" data-node-type="icon" id="el_1697995591336_620">
# </span>
# <span data-node-type="text" id="el_1697995591336_619"><span style="color: rgb(255, 235, 59);">Ultimate</span> Placement Solution</span>
# </button></a>
# </div>
# </div>
# <div class="col span_6_of_12 span_6_of_12-tl span_12_of_12-tp span_12_of_12-sl span_12_of_12-sp flex-item js-lw-flexible-wrapper js-same-content-child learnworlds-align-center" data-node-type="column" id="el_1697995591336_613">
# <div class="lw-widget-in learnworlds-image learnworlds-bg-default learnworlds-framed-image learnworlds-element stretched-bg learnworlds-frame-size-very-large square" data-element-id="framedImageRectangle" data-node-type="framedImage" id="el_1697995591336_616" style='background-image: url("https://lwfiles.mycourse.app/62a6cd5e1e9e2fbf212d608d-public/0861d8b3ac594a2e337bbf3618d48331.png");'></div></div>
# </div>
# </div>
# </section><section class="js-learnworlds-section learnworlds-section stretched-bg learnworlds-size-small js-change-image-node lw-brand-bg" data-magic="background-image" data-section-id="tplProgress3" id="section_1655917358400_387" style="">
# <div class="js-video-wrapper" style="display: none;"></div>
# <div class="learnworlds-section-overlay lw-dark-bg js-learnworlds-overlay" style="display: none;"></div>
# <div class="learnworlds-section-content js-learnworlds-section-content wide js-lw-flexible-wrapper" id="history_1684513902080_525">
# <h3 class="lw-widget-in learnworlds-heading3 learnworlds-heading3-normal learnworlds-element" data-element-id="heading1Normal" data-node-type="text" id="el_1655917953102_458" style=""><div style="text-align: center;">India's Most Loved Coding Community ❤️</div></h3><div class="lw-cols align-items-stretch with-flexible-parts one-row-tl multiple-rows-tp multiple-rows-sl main js-same-content-wrapper multiple-rows-sp one-row learnworlds-align-center justify-center" data-node-type="columnWrapper" id="el_1655925815735_1276" style="">
# <div class="col span_3_of_12 span_3_of_12-tl span_6_of_12-tp mb-4rem-tp span_6_of_12-sl mb-4rem-sl span_12_of_12-sp mb-4rem-sp flex-item js-same-content-child flexible" data-node-type="column" id="el_1655925815735_1261">
# <div class="js-lw-flexible-wrapper lw-widget-in lw-progress-wrapper learnworlds-align-center js-same-content-wrapper full" data-element-id="iconProgress3" data-node-type="progress" id="el_1655925815735_1262">
# <div class="with-flexible-parts align-items-center">
# <div class="flexible-part">
# <span class="learnworlds-subheading learnworlds-subheading-small no-margin-bottom learnworlds-icon fas fa-users" data-element-id="icon-check-circle" data-magic="icon" data-node-type="icon" id="el_1655925815735_1263"></span>
# </div>
# <div class="flexible-part">
# <div class="lw-progress">
# <div class="progress-container_counter progress-container_counter--numeric">
# <h3 class="lw-widget-in learnworlds-heading3 learnworlds-heading3-normal learnworlds-element" data-element-id="heading2Normal" data-node-type="counter-text" id="el_1655925815735_1264"></h3>
# </div>
# </div>
# </div>
# </div>
# <div class="learnworlds-overline-text learnworlds-element" data-element-id="textNormal" data-magic="title" data-node-type="text" id="el_1655925815735_1265">Happy Learners </div>
# </div>
# </div>
# <div class="col span_3_of_12 span_3_of_12-tl span_6_of_12-tp mb-4rem-tp span_6_of_12-sl mb-4rem-sl span_12_of_12-sp mb-4rem-sp flex-item js-same-content-child flexible" data-node-type="column" id="el_1655925815735_1266">
# <div class="js-lw-flexible-wrapper lw-widget-in lw-progress-wrapper learnworlds-align-center js-same-content-wrapper full" data-element-id="iconProgress3" data-node-type="progress" id="el_1655925815735_1267">
# <div class="with-flexible-parts align-items-center">
# <div class="flexible-part">
# <span class="learnworlds-subheading learnworlds-subheading-small no-margin-bottom learnworlds-icon fas fa-hand-holding-heart" data-element-id="icon-check-circle" data-magic="icon" data-node-type="icon" id="el_1655925815735_1268"></span>
# </div>
# <div class="flexible-part">
# <div class="lw-progress">
# <div class="progress-container_counter progress-container_counter--numeric">
# <h3 class="lw-widget-in learnworlds-heading3 learnworlds-element learnworlds-heading3-normal" data-element-id="heading2Normal" data-node-type="counter-text" id="el_1655925815735_1269"></h3>
# </div>
# </div>
# </div>
# </div>
# ...
# </div>
# <div class="login-form-input-wrapper form-input-wrapper mb-15 extra-form-input-wrapper js-extraLogin_university">
# <label class="landing-form-input-lbl learnworlds-main-text-small mb-5" for="university">Your university?</label>
# <input class="landing-form-input learnworlds-input no-margin-bottom learnworlds-input-small learnworlds-input-solid-light" id="university" name="university" placeholder="University" type="text"/>
# </div>
# <div class="login-form-input-wrapper form-input-wrapper mb-15 extra-form-input-wrapper js-extraLogin_graduation_date">
# <label class="landing-form-input-lbl learnworlds-main-text-small mb-5" for="graduation_date">Your graduation year?</label>
# <input class="landing-form-input learnworlds-input no-margin-bottom learnworlds-input-small learnworlds-input-solid-light" id="graduation_date" max="2050" min="1950" name="graduation_date" placeholder="Graduation Year" type="number"/>
# </div>
# <div class="login-form-input-wrapper form-input-wrapper mb-15 extra-form-input-wrapper js-extraLogin_terms flex-wrap flex a-i-fs">
# <input class="lnd-checkmark-checkbox learnworlds-icon" id="acceptTerms" name="terms" type="checkbox"/>
# <label class="lnd-checkmark-lbl" for="acceptTerms"></label>
# <div class="lnd-form-link-wrapper learnworlds-main-text-very-small">
# <span class="lnd-form-link-lbl">I accept the</span>
# <a class="lnd-form-link" href="/terms" target="_blank">Terms &amp; Conditions</a>
# <span class="lw-field-required-asterisk learnworlds-main-text-very-small js-required-indicator js-required-indicator-terms" style="display:none;">*</span>
# </div>
# </div>
# <div class="login-form-input-wrapper form-input-wrapper mb-15 extra-form-input-wrapper flex a-i-fs js-extraLogin_optin">
# <input class="lnd-checkmark-checkbox learnworlds-icon" id="acceptMarketing" name="optin" type="checkbox"/>
# <label class="lnd-checkmark-lbl" for="acceptMarketing"></label>
# <div class="lnd-form-link-wrapper learnworlds-main-text-very-small">
# <span class="lnd-form-link-lbl js-registration-optin-text">I would like to receive news, tips and tricks, and other promotional material</span>
# </div>
# </div>
# </div>
# <button class="landing-form-small-button signup-btn js-enterFocus learnworlds-button learnworlds-button-small learnworlds-button-solid-brand w-full mb-30" type="button">
# <div class="btn-loader a-i-c j-c-sb">
# <div class="btn-loader-part part1"></div>
# <div class="btn-loader-part part2"></div>
# <div class="btn-loader-part part3"></div>
# </div>
# <span class="btn-lbl">Start your learning journey</span>
# </button>
# <div class="-form-create-forgot flex a-i-c j-c-sb">
# <div class="inline-block -sign-in js-signInLinks">
# <a class="learnworlds-main-text-very-small" href="javascript:void(0)">Sign in with your account</a>
# </div>
# <div class="inline-block -forgot-pass">
# <a class="learnworlds-main-text-very-small" href="javascript:void(0)">Forgot your password?</a>
# </div>
# </div>
# </div>
# <!-- SSO block -->
# <div id="ssoBlock">
# <div class="-or learnworlds-main-text-normal flex a-i-c j-c-c mb-20 lw-text-color-fadeout50" id="ssoOr" style="margin-top:10px"><span>or</span></div>
# </div>
# <span></span>
# <!-- END SSO block -->
# </div>
# <div class="landing-form js-form-enterkey p-30" id="passwordResetInitForm" style="display: none;">
# <button aria-label="Close" class="close-animatedModal" type="button"><span aria-hidden="true" class="login-form-close learnworlds-icon fas fa-times"></span></button>
# <!--<img class="login-form-logo js-login-form-school-logo"/>-->
# <div class="landing-form-title learnworlds-heading3-small mb-30">Get a brand new password!</div>
# <div class="-form-inputs">
# <div class="login-form-input-wrapper mb-30 email-input-wrapper">
# <label class="landing-form-input-lbl learnworlds-main-text-small mb-5" for="reset-email">What's your e-mail?</label>
# <input autocomplete="email" class="landing-form-input js-reset-pass-input learnworlds-input no-margin-bottom learnworlds-input-small learnworlds-input-solid-light" id="reset-email" name="email" placeholder="E-mail" type="email"/>
# </div>
# <div aria-atomic="true" aria-live="assertive" class="error-wrapper p-5-10 mb-20" role="alert" style="display: none;">
# <p class="learnworlds-main-text no-margin-bottom learnworlds-main-text-very-small js-reset-pass-error-msg"></p>
# </div>
# </div>
# <div class="-form-buttons flex a-i-c j-c-c">
# <button class="landing-form-small-button reset-pass-btn js-enterFocus learnworlds-button-small learnworlds-button learnworlds-button-solid-brand" type="button">
# <div class="btn-loader a-i-c j-c-sb">
# <div class="btn-loader-part part1"></div>
# <div class="btn-loader-part part2"></div>
# <div class="btn-loader-part part3"></div>
# </div>
# <span class="btn-lbl">OK</span>
# </button>
# <button class="landing-form-small-button js-animated-close close-animatedModal learnworlds-button-small learnworlds-button learnworlds-button-solid-brand" style="position: relative; top: 0px;" type="button">
# <span class="btn-lbl">cancel</span>
# </button>
# </div>
# </div>
# <div class="landing-form js-form-enterkey p-30" id="passwordResetForm" style="display: none;">
# <button aria-label="Close" class="close-animatedModal" type="button"><span aria-hidden="true" class="login-form-close learnworlds-icon fas fa-times"></span></button>
# <!--<img class="login-form-logo js-login-form-school-logo"/>-->
# <div class="landing-form-title learnworlds-heading3-small mb-30">Get a brand new password!</div>
# <div class="-form-inputs">
# <div data-role="password-meter-reset-password-presentation">
# <div class="login-form-input-wrapper mb-30 email-input-wrapper">
# <label class="landing-form-input-lbl learnworlds-main-text-small mb-5">Enter it below, please</label>
# <input class="landing-form-input js-new-pass-input learnworlds-input no-margin-bottom learnworlds-input-small learnworlds-input-solid-light" name="password" placeholder="Password" type="password"/>
# </div>
# <div class="login-form-input-wrapper mb-30 email-input-wrapper">
# <label class="landing-form-input-lbl learnworlds-main-text-small mb-5">Enter it once more, please <span class="lw-field-required-asterisk learnworlds-main-text-very-small">*</span></label>
# <input class="landing-form-input js-new-pass-input learnworlds-input no-margin-bottom learnworlds-input-small learnworlds-input-solid-light" name="password_confirm" placeholder="Password" type="password"/>
# </div>
# </div>
# <div aria-atomic="true" aria-live="assertive" class="error-wrapper p-5-10 mb-20" role="alert" style="display: none;">
# <p class="learnworlds-main-text no-margin-bottom learnworlds-main-text-very-small js-new-pass-error-msg">
# </p>
# </div>
# </div>
# <div class="-form-buttons flex a-i-c">
# <button class="landing-form-small-button reset-pass-final-btn js-enterFocus learnworlds-button-small learnworlds-button learnworlds-button-solid-brand" type="button">
# <span class="btn-lbl">OK</span>
# </button>
# <button class="landing-form-small-button js-animated-close close-animatedModal learnworlds-button-small learnworlds-button learnworlds-button-solid-brand" style="position: relative; top: 0px;" type="button">
# <span class="btn-lbl">cancel</span>
# </button>
# </div>
# </div>
# <script id="userCustomField" type="text/x-jquery-tmpl">
#         <div class="login-form-input-wrapper mb-15 user-custom-field form-input-wrapper extra-form-input-wrapper js-extraLogin_{{=key}} learnworlds-main-text-normal" style="display:block;opacity:1;">
#             {{#if type != "checkbox"}}
#             <label class="landing-form-input-lbl learnworlds-main-text-small mb-5 word-break" for="extralogin-{{=key}}">{{=signup_name}} {{#if required}}<span class="lw-field-required-asterisk learnworlds-main-text-very-small">*</span>{{/if}}</label>
#             {{/if}}
#                 {{#if type == "text"}}
#                     <input type="text" id="extralogin-{{=key}}" class="landing-form-input learnworlds-input no-margin-bottom learnworlds-input-small learnworlds-input-solid-light" placeholder="{{=placeholder}}" value="{{=defaultValue}}" data-key="{{=key}}" name="extralogin-{{=key}}" {{#if maxLength }}maxlength="{{=maxLength}}"{{/if}} />
#                 {{/if}}
#
#                 {{#if type == "textarea"}}
#                     <textarea id="extralogin-{{=key}}" class="landing-form-input learnworlds-input no-margin-bottom learnworlds-input-small learnworlds-input-solid-light" placeholder="{{=placeholder}}" data-key="{{=key}}" value="{{=defaultValue}}" name="extralogin-{{=key}}" {{#if maxLength }}maxlength="{{=maxLength}}"{{/if}}>{{=defaultValue}}</textarea>
#                 {{/if}}
#
#                 {{#if type == "checkbox"}}
#                     <div class="flex a-i-fs">
#                         <input class="lnd-checkmark-checkbox learnworlds-icon" name="extralogin-{{=key}}" type="checkbox" id="extralogin-{{=key}}" {{#if defaultValue == true}}checked{{/if}} data-key="{{=key}}">
#                         <label for="extralogin-{{=key}}" class="lnd-checkmark-lbl"></label>
#                         <div class="lnd-form-link-wrapper learnworlds-main-text-very-small">
#                             <span class="lnd-form-link-lbl">{{=checkbox_label!}}</span> {{#if required}}<span class="lw-field-required-asterisk learnworlds-main-text-very-small">*</span>{{/if}}
#                         </div>
#                     </div>
#                 {{/if}}
#
#                 {{#if type == 'dropdown' OR type == "country"}}
#                     <div class="select-wrapper">
#                         {{#if searchDropdown == true}}
#                             <!-- Combined input and dropdown -->
#                             <div data-role="custom-dropdown-menu">
#                             </div>
#                         {{/if}}
#                         <select id="extralogin-{{=key}}" name="extralogin-{{=key}}" class="learnworlds-input no-margin-bottom learnworlds-input-small learnworlds-input-solid-light js-custom-form-input-dropdown {{#if defaultValue == '' OR defaultValue == null}}lw-custom-field-placeholder-selected{{/if}}" data-key="{{=key}}" style="{{#if searchDropdown == true}}display: none;{{/if}}">
#                             {{#if placeholder}}
#                                 <option value="" {{#if defaultValue == '' OR defaultValue == null}}selected{{/if}} {{#if required}}disabled{{/if}}>{{=placeholder}}</option>
#                             {{/if}}
#                             {{#each options}}
#                                 <option value="{{=field_value}}" {{#if $view.parent.parent.data.defaultValue == field_value}}selected{{/if}}>{{=field_name}}</option>
#                             {{/each}}
#                         </select>
#                     </div>
#                 {{/if}}
#
#                 {{#if type == 'radio'}}
#                     <input type="radio" name="extralogin-{{=key}}" data-key="{{=key}}" value="" {{#if !defaultValue}}checked{{/if}} style="display: none">
#                     {{#each options}}
#                         <label class="learnworlds-custom-radio-lbl flex a-i-fs p-5-0">
#                             <input class="learnworlds-input-radio" type="radio" name="extralogin-{{=$view.parent.parent.data.key}}" data-key="{{=$view.parent.parent.data.key}}" value="{{=field_value}}" {{#if isDefault==true}}checked{{/if}}>
#                             <span class="learnworlds-input-radio-circle mr-5"></span>
#                             <span class="learnworlds-main-text-very-small">{{=field_name}}</span>
#                         </label>
#                     {{/each}}
#                 {{/if}}
#             {{#if type == 'date'}}
#                 <input type="text" id="extralogin-{{=key}}" class="landing-form-input js-custom-form-input-date no-margin-bottom learnworlds-input learnworlds-input-small learnworlds-input-solid-light" placeholder="{{=placeholder}}" value="{{=defaultValue}}" data-key="{{=key}}" name="extralogin-{{=key}}" />
#             {{/if}}
#
#             {{#if type == 'datetime'}}
#                 <input type="datetime-local" id="extralogin-{{=key}}" step="60" class="landing-form-input js-custom-form-input-datetime no-margin-bottom learnworlds-input learnworlds-input-small learnworlds-input-solid-light" placeholder="{{=placeholder}}" value="{{=defaultValue}}" data-key="{{=key}}" name="extralogin-{{=key}}" />
#                 <input type="hidden" name="extralogin-{{=key}}_submit" value="{{=defaultValue}}" />
#             {{/if}}
#          </div>
# </script>
# <script>
#         $(document).ready(function(){
#             let inactiveFields = [".js-extraLogin_phone",".js-extraLogin_address",".js-extraLogin_country",".js-extraLogin_birthday",".js-extraLogin_company",".js-extraLogin_country_dropdown",".js-extraLogin_website",".js-extraLogin_university",".js-extraLogin_graduation_date",".js-extraLogin_terms",".js-extraLogin_company_size",".js-extraLogin_profession",".js-extraLogin_optin"];
#             if(inactiveFields.length){
#                 inactiveFields.forEach(function(field){
#                     $(field).remove();
#                 });
#             }
#         });
# </script>
# <script>
#                 // Closest is not supported on IE11
#                 function isDescendantOfNodeWithClass (element, className) {
#                     var el = element;
#
#                     do {
#                         if (el.classList.contains(className)) {
#                             return true;
#                         }
#
#                         el = el.parentElement || el.parentNode;
#                     } while (el !== null && el.nodeType === 1);
#
#                     return false;
#                 }
#
#
#                 function detectImageElementsInView () {
#                     var allImageElements = document.querySelectorAll('[data-node-type="framedImage"], [data-node-type="screen"]');
#
#                     // Display image elements inside a popup right away
#                     var imageElementsInPopup = Array.prototype.filter.call(allImageElements, function(el) { return isDescendantOfNodeWithClass(el, 'popup') });
#                     imageElementsInPopup.forEach(function (el){ return el.classList.add('in-view'); });
#                     // Observe the rest ones
#                     var excludedIds = imageElementsInPopup.map(function (el){ return el.id; });
#                     var imageElementsToObserve = Array.prototype.filter.call(allImageElements, function (el){ return excludedIds.indexOf(el.id) === -1; });
#
#                     if ('IntersectionObserver' in window) {
#                         var observerOptions = {
#                             root:  document.body,
#                             rootMargin: '0px 0px',
#                         };
#                         var observer = new IntersectionObserver(function (entries){
#                             entries.forEach(function (entry){
#                                 if (entry.isIntersecting) {
#                                     entry.target.classList.add('in-view');
#                                     observer.unobserve(entry.target);
#                                 }
#                             })
#                         }, observerOptions);
#                         imageElementsToObserve.forEach(function (el){ return observer.observe(el); });
#                     } else {
#                         imageElementsToObserve.forEach(function (el){ return el.classList.add('in-view'); });
#                     }
#                 }
#                 window.addEventListener('load', detectImageElementsInView);
#             </script>
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-WM5R98Q2" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script chat="true" src="//in.fw-cdn.com/32025875/1074780.js" type="text/javascript"></script>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WM5R98Q2" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# </body>
# </html>
